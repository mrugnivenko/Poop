# %%
import numpy as np
from numpy import linalg
import math
from matplotlib import pylab as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
def surface_plot (matrix, **kwargs):
    # acquire the cartesian coordinate matrices from the matrix
    # x is cols, y is rows
    (x, y) = np.meshgrid(np.arange(matrix.shape[1]), np.arange(matrix.shape[0]))
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(x, y, matrix, **kwargs)
    return (fig, ax, surf)

# %%
def plot_it(txt_file):
    u = read_dataset(txt_file)

    (fig, ax, surf) = surface_plot(u, cmap=plt.cm.coolwarm)

    fig.colorbar(surf)

    ax.set_xlabel('p')
    ax.set_ylabel('slaves (cores)')
    ax.set_zlabel('u (values)')

    plt.show()

# %%
n_to_read = 6
d_to_read = 9

# %%
def read_dataset(file_name):
    global n_to_read
    global d_to_read
    out = np.zeros((n_to_read, d_to_read))
    f = open(file_name, 'r')
    for i in range(n_to_read):
        s = f.readline()
        tokens = s.split(' ')
        line_to_write = []
        for j in range(d_to_read):
            tok_tok = []
            tok_tok = str(tokens[j]).split('_')
            line_to_write.append(tok_tok[1])
            out[i][j] = line_to_write[j]
    return out

# %%
plot_it("plots8.txt")
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %% [markdown]
# lets look at the same plot but with $cores\in [4, 7)$ and $p\in[5, 10)$

# %%
n_to_read = 4
d_to_read = 5
plot_it("plots8_but_precizely.txt")
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
n_to_read = 4
d_to_read = 5
plot_it("plots1_with_delays.txt")
